# %% [markdown]
# # Лабораторная работа 4
# ### Бинаризация

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
import sys
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np

# Изменим стандартный размер графиков matplotlib
plt.rcParams["figure.figsize"] = [6, 4]
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
image1 = cv.imread('./china.png')
gray_image1 = cv.cvtColor(image1, cv.COLOR_BGR2GRAY)
channels = [0]
histSize = [256]
range = [0, 256]

gs = plt.GridSpec(1, 2)
plt.figure(figsize=(10, 8))
plt.subplot(gs[0])
plt.imshow(gray_image1, cmap='gray')
plt.xticks([]), plt.yticks([])
plt.subplot(gs[1])
plt.hist(gray_image1.reshape(-1), 256, range)
plt.show()

# %% [markdown]
# В библиотеке OpenCV есть функция для бинаризации изображений cv.threshold(), для применения пороговых значений. Функция принимает несколько параметров:
# - image — изображение, к которому применяется бинаризация;
# - threshold — пороговое значение;
# - maxval — максимальное значение, которое присваивается значениям пикселей, превышающим пороговое значение;
# - type — тип порога.

# %%
threshold = 100
image = gray_image1

ret, thresh1 = cv.threshold(image, threshold, 255, cv.THRESH_BINARY)

plt.figure(figsize=(15, 8))
plt.imshow(thresh1, 'gray', vmin=0, vmax=255)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1083.5), np.float64(181.5), np.float64(-0.5))

# %% [markdown]
# ### Текст, распознанный Google переводчиком

# %%
res1 = cv.imread('./china_res1.jpg')
res2 = cv.imread('./china_res2.jpg')

gs = plt.GridSpec(1, 2)
plt.figure(figsize=(14, 5))
plt.subplot(gs[0])
plt.imshow(res1, cmap='gray')
plt.axis("off")
plt.subplot(gs[1])
plt.imshow(res2, cmap='gray')
plt.axis("off")
plt.show()
